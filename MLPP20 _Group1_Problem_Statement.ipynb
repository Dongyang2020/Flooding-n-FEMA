# %% [markdown]
# # MLPP20 MIDTERM - Group 1
#
# ## Impacts of flooding on vulnerable U.S. communities
#
# #### Humayoun Akram, Sam Seo, Dongyang Wei, Caroline Williams
#
# <img src="https://ewscripps.brightspotcdn.com/dims4/default/1f91c12/2147483647/strip/true/crop/3000x1688+0+156/resize/1280x720!/quality/90/?url=https%3A%2F%2Fewscripps.brightspotcdn.com%2Fef%2F97%2F1da36fdf4dd6aaf9f18f2055ef46%2Fgettyimages-1137457674.jpg" width=500>

# %% [markdown]
# **(GGD: Overall thoughts are that this is a great first draft!  The background could use more specifics to cut back on the vague language.  Examples and more references could be included [perhaps in the academic literature?  you might want to try a google scholar search on some of these topics] to drive the various points home and motivate specific aspects of the project.)**

# %% [markdown]
#   ## Background(HA)
#
#   Efforts to master the environment around us have been one of the distinctive features of our species. **(GGD: I'm not sure what you mean by "master" the environment.)** In our endeavors to control and take maximum benefit from nature, we have created technologies that harnessed the elements and processes around us, and resultingly, diverted our energies to other pursuits. **(GGD: This is very abstract.  Are you referring to energy generation?  More specifics might clarify.)** However, our knowledge of natural phenomena was always incomplete. **(GGD: Well, this is always true.  But what does "incomplete" mean here?  Where is our knowledge lacking and why is this important?  What are these "natural phenomena"?  Can you give some examples?)**
#
#   ~~Needless to say,~~ **(GGD: too informal)** we have always contended with natural disasters. And with increasing populations, this struggle is compounded, with more and more humans living closer and closer to places which are at risk. **(GGD: why are people congregating around places that are at risk?  Or is it that they've always congregated around places that are at risk, it's just that there's more of them now?)** Governments are inevitably tasked with the management of resources, minimizing risk, and helping vulnerable communities to rebuild if they cannot cope on their own.
#
#   In 2017, the U.S. experienced more than [$307 billion of economic damages](https://www.thebalance.com/cost-of-natural-disasters-3306214) as a result of [natural disasters](https://www.statista.com/topics/1714/natural-disasters/#dossierSummary__chapter1). According to the [congressional budget office](https://www.cbo.gov/system/files/2019-04/55019-ExpectedCostsFromWindStorm.pdf), a majority of these losses were the result of flooding. According to ~~the report~~ **(GGD: a report)** from the [NYU Furman Center](https://furmancenter.org/files/Floodplain_PopulationBrief_12DEC2017.pdf), nearly ten percent of the U.S. population ~~live~~ **(GGD: lives)** in floodplains. For most states, the population living in the combined 100 and 500-year floodplains is less than ten percent of ~~state’s total population~~ **(GGD: the total)**, while Arizona (64%), Florida (26%) and North Dakota (20%) have the largest percentages.
#
#   Institutions meant to mitigate risk and losses from storm events have been in place for ~~for~~ more than 200 years. Initially, it **(GGD: what is "it"?)** was done on an ad-hoc basis through legislation until the Federal Disaster Management Agency was created in 1930. In 1978 it became the independent Federal Emergency Management Agency(FEMA), until 2003, when it was brought under the directive of Homeland Security. The agency is responsible for not only helping during the disasters but also help residents to move out of the vulnerable areas through home buyout programs. With the number of ["billion-dollar weather and climate disasters](https://www.washingtonpost.com/news/energy-environment/wp/2018/01/08/hurricanes-wildfires-made-2017-the-most-costly-u-s-disaster-year-on-record/?wpisrc=nl_energy202&wpmm=1)" **(GGD: move closing quotes into link)** on the rise, FEMA's [annual budget of $18 billion](https://en.wikipedia.org/wiki/Federal_Emergency_Management_Agency) will be stretched thinner, with increasing pressure to utilize funds ~~to~~ effectively and equitably.

# %% [markdown]
# ## ~~Perspectives(DW SS)~~ **(GGD: this section should be combined with the above section into one "Introduction")**
#
# County level Studies in **(GGD: the)** US show that people in coastal areas [build~~ing~~ less in high risk flood prone areas](https://www-tandfonline-com.udel.idm.oclc.org/doi/pdf/10.1080/24694452.2017.1320214?needAccess=true). However, this trend is not observed in the case of their inland counterparts. According to the lead **(GGD: why "lead" author?)** author in this study on changing exposures to risk, "~~…~~ ... people in coastal areas are more aware of flood threats than those living in inland flood zones, and that populations in inland areas are increasing.” Job opportunity and lower cost of housing motivate people to buy houses and live in those flood-prone areas. **(GGD: why are job opportunities and low cost of housing particularly available in flood-prone areas?)** These factors create conditions of vulnerability, with ~~under resourced~~ **(GGD: under-resourced)** populations being less likely to cope with the economic and health hazards that come with damaging floods. **(GGD: why are these populations under-resourced?)**
#
# This raises **(GGD: the)** question of how policies should support communities vulnerable to ~~the~~ natural disasters. Increasingly, U.S. based studies indicate that people of low income and minority status are not just more susceptible to disasters, but that ["such communities will have to bear a disproportionate share of adaptation costs"](https://www.nyserda.ny.gov/-/media/Files/Publications/Research/Environmental/EMEP/climaid/ClimAID-Report.pdf). FEMA's mandate is primarily to coordinate responses to overwhelming disasters, but also to provide relief and rebuild in those affected areas. In the past 30 years, the agency has supported buyouts of [43,000 properties](https://advances.sciencemag.org/content/5/10/eaax8995), as homeowners look to relocate. For some perspective, one study shows that over [41 million Americans](https://iopscience.iop.org/article/10.1088/1748-9326/aaac65) live on *inland* properties that are within the 1% annual exceedance probability floodplain, which means there is a 26% chance it will be flooded [every 30 years](https://www.usgs.gov/special-topic/water-science-school/science/floods-and-recurrence-intervals?qt-science_center_objects=0#qt-science_center_objects). In addition to these concerns of scale, some studies go so far as to observe that rich counties [are getting more federal help](https://www.nytimes.com/2019/10/09/climate/disaster-flood-buyouts-climate-change.html)) in order to cope with natural disasters. Moreover, there is evidence that climate change will increase the [serverity of storms](https://www.pnas.org/content/116/43/21450), and the resulting damages to human life and well-being.

# %% [markdown]
# ##Problem Statement(CW, HA, DW, SS)
#
# This ~~data analysis~~ **(GGD: project)** will explore the impacts of inland flooding on communities, as viewed through the lens of demographic characteristics and the distribution of federal relief funding. Economic strength can describe a community's capacity to support a healthy populace, and its ability to weather harmful influences. Social cohesion and diversity can characterize a group's ability to rebuild, while a lack therof may indicate ~~a under resourced~~ **(GGD: an under-resourced)** and marginalized population. And education levels can indicate stability and the potential for growth. **(GGD: for these last two sentences, do you have any references indicating that this is known to be true?)**  Flooding may have long-term effects beyond the deterioration of built infrastructure in the absence of these forms of resilience. FEMA's objectives including aiding people who are forced to rebuild or relocate as a result of disaster, and in examining the recent history of this ~~agencies~~ **(GGD: agency's)** efforts, we will ~~ask~~ **(GGD: address)** the following questions:
#
# *   **What is the correlation between flood impacts and the socio-economic status of counties across the US?**
#
# *  **To what extent is federal government flood relief funding serving vulnerable communities?**
#
# Preliminary and subsequent inquiries will explore correlations between total flood losses and the strength of an economy. For example, one could assume that a city with more buildings, when compared to a smaller town, would generally have higher **(GGD: total dollar)** amounts in flood losses because there is more exposure. The measure for the strength of the economy will be determined in the coming weeks of this analysis, but could include either mean property value or GDP, per county. In addition, correlations between flood losses and non-white populations, poverty levels, and education levels might illuminate disproportionate burdens of adaptation that are placed on marginalized communities.
#
# FEMA's housing acquisition program, also known as a ‘buy-out’ program where the government buys properties that exist in risky areas. **(GGD: this sentence is missing a verb.)** There has been much criticism regarding the disparity in who the program serves, and thus it has reason to be investigated. This form of insurance is a contentious policy, and our analysis may indicate some means **(GGD: careful, we'll have to see how it shakes out, but typically with these kind of data-driven analyses you'll be providing evidence for how things are, not necessarily the "right" way to move forward)** of improving the focus and delivery of these funds.

# %% [markdown]
# # ***WORK IN PROGRESS***
# ## Description of Data Sets and Data Dictionary
#
# Identify Data Sets
#
# This investigation will largely use the Storm Events Database created by the National Oceanic and Atmospheric Administration (NOAA) to compare losses (in US Dollars) due to flood and flash flood events for each county in the US since 1996. The flood event data will be compared with data from the US Census Bureau, Bureau of Economic Analysis (BEA), and the Federal Emergency Management Administration (FEMA).
#
# Summarize with Tables and Plots
#
# ....

# %% [markdown]
# **(GGD: the below are very good paths forward.  Let's try and set up a video chat to discuss how to frame these in an ML context.)**

# %% [markdown]
# ** Steps for analysis
#
#
#
# *   **Is there a trend between total flood losses in a county since 1996 and the strength of its economy, across all US counties?**
#
#   This subquestion will help reveal whether there is a correlation between total flood losses and the strength of an economy. For example, one could assume that a city with more buildings, when compared to a smaller town, would generally have higher amounts in flood losses because there is more exposure. The measure for the strength of the economy will be determined in the coming weeks of this analysis, but could include either mean property value or GDP, per county.
# Answering this subquestion will also help "normalize" the data by creating a ratio which can serve as a better comparison between different counties. Each event will have a "flood impact score" which compares the flood losses to the county's GDP or median property values. Thus, an event with a high flood impact score would signify that the flood losses (in dollars) had a large impact on the county's available budget and economy. A low flood impact score would signify that the flood event is nearly negligible. This subquestion will likely be analyzed through a supervised learning technique.
#
# *   **For all flood events since 1996, is there a correlation between flood impacts in a county and its proportion of minority population, for all US counties?**
#
#   This subquestion begins to evaluate the correlation between flood losses and demographic data per county. A flood event's flood impact score will be compared with the 'percent of non-white population' for the county in which the event took place. The method to investigate this subquestion will likely require a supervised learning technique
#
# *   **For all flood events since 1996, is there a correlation between flood impacts in a county and the percentage of people living in poverty, for all US counties?**
#
#   This subquestion also investigates relationships between flood losses and demographic data, this time by comparing poverty statistics. Similarly, a supervised learning technique will likely be used
#
# *   **For all flood events since 1996, is there a correlation between flood impacts in a county and the average level of education for all US counties?**
#
#   This subquestion similarly compares flood losses with level of education data for each county. A supervised learning technique will likely be used.
#
# *   **What is the relationship between geographic location, flood impact, and demographic data (for race, poverty, and education)?**
#
#   The comparison between flood impact and demographics can also be evaluated spatially through an unsupervised machine learning approach. This subquestion will reveal if there are geographic trends in losses and vulnerabilities across the US.
#
# *   **Where is FEMA mitigation spending taking place, and is the spending taking place in  vulnerable communities?**
#
#   The investigation will then aim to compare the socio-economic elements of flood loss data with FEMA mitigation policies and funding. This will likely include a spatial analysis with an unsupervised machine learning approach.
#
# *   **Where are FEMA housing acquisitions taking place, and are the acquisitions taking place in affected vulnerable communities?**
#
#   FEMA has a housing acquisition program, also known as a ‘buy-out’ program where the government buys properties that exist in risky areas. There has been much criticism regarding the disparity in who the program serves, and thus it has reason to be investigated. This will likely include a spatial analysis with an unsupervised machine learning approach.
